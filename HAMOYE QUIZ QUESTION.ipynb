# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('FoodBalanceSheets.csv')
df.to_csv('FoodBalanceSheets.csv')

# %%
print(df)
# Out:
#        Unnamed: 0  Unnamed: 0.1  Area Code      Area  Item Code  \
# 0               0             0          4   Algeria       2501
# 1               1             1          4   Algeria       2501
# 2               2             2          4   Algeria       2901
# 3               3             3          4   Algeria       2901
# 4               4             4          4   Algeria       2901
# ...           ...           ...        ...       ...        ...
# 60938       60938         60938        181  Zimbabwe       2899
# 60939       60939         60939        181  Zimbabwe       2899
# 60940       60940         60940        181  Zimbabwe       2899
# 60941       60941         60941        181  Zimbabwe       2899
# 60942       60942         60942        181  Zimbabwe       2899
#
#                 Item  Element Code                                 Element  \
# 0         Population           511           Total Population - Both sexes
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Unnamed: 0.1       0
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Area Code     Area  Item Code         Item  \
# 0           0             0          4  Algeria       2501   Population
# 1           1             1          4  Algeria       2501   Population
# 2           2             2          4  Algeria       2901  Grand Total
# 3           3             3          4  Algeria       2901  Grand Total
# 4           4             4          4  Algeria       2901  Grand Total
#
#    Element Code                                 Element             Unit  \
# 0           511           Total Population - Both sexes     1000 persons
# 1          5301                Domestic supply quantity      1000 tonnes
# 2           664           Food supply (kcal/capita/day)  kcal/capita/day
# 3           674  Protein supply quantity (g/capita/day)     g/capita/day
# 4           684      Fat supply quantity (g/capita/day)     g/capita/day
#
#       Y2014     Y2015     Y2016     Y2017     Y2018
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Area Code      Area  Item Code  \
# 60938       60938         60938        181  Zimbabwe       2899
# 60939       60939         60939        181  Zimbabwe       2899
# 60940       60940         60940        181  Zimbabwe       2899
# 60941       60941         60941        181  Zimbabwe       2899
# 60942       60942         60942        181  Zimbabwe       2899
#
#                 Item  Element Code                                 Element  \
# 60938  Miscellaneous          5142                                    Food
# 60939  Miscellaneous           645     Food supply quantity (kg/capita/yr)
# 60940  Miscellaneous           664           Food supply (kcal/capita/day)
# 60941  Miscellaneous           674  Protein supply quantity (g/capita/day)
# 60942  Miscellaneous           684      Fat supply quantity (g/capita/day)
#
#                   Unit  Y2014  Y2015  Y2016  Y2017  Y2018
# 60938      1000 tonnes  42.00  46.00  33.00  19.00  16.00
# ...

# %%
df.isnull()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Area Code   Area  Item Code   Item  \
# 0           False         False      False  False      False  False
# 1           False         False      False  False      False  False
# 2           False         False      False  False      False  False
# 3           False         False      False  False      False  False
# 4           False         False      False  False      False  False
# ...           ...           ...        ...    ...        ...    ...
# 60938       False         False      False  False      False  False
# 60939       False         False      False  False      False  False
# 60940       False         False      False  False      False  False
# 60941       False         False      False  False      False  False
# 60942       False         False      False  False      False  False
#
#        Element Code  Element   Unit  Y2014  Y2015  Y2016  Y2017  Y2018
# 0             False    False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Unnamed: 0.1       0
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1     Area Code     Item Code  Element Code  \
# count  60943.000000  60943.000000  60943.000000  60943.000000  60943.000000
# mean   30471.000000  30471.000000    134.265576   2687.176706   3814.856456
# std    17592.873065  17592.873065     72.605709    146.055739   2212.007033
# min        0.000000      0.000000      4.000000   2501.000000    511.000000
# 25%    15235.500000  15235.500000     74.000000   2562.000000    684.000000
# 50%    30471.000000  30471.000000    136.000000   2630.000000   5142.000000
# 75%    45706.500000  45706.500000    195.000000   2775.000000   5511.000000
# max    60942.000000  60942.000000    276.000000   2961.000000   5911.000000
#
#                Y2014          Y2015          Y2016          Y2017  \
# count   59354.000000   59395.000000   59408.000000   59437.000000
# mean      134.196282     135.235966     136.555222     140.917765
# std      1567.663696    1603.403984    1640.007194    1671.862359
# ...

# %%
df['Area Code'].describe()
# Out:
# count    60943.000000
# mean       134.265576
# std         72.605709
# min          4.000000
# 25%         74.000000
# 50%        136.000000
# 75%        195.000000
# max        276.000000
# Name: Area Code, dtype: float64

# %%
plt.figure(figsize = (10,10)) 
plt.subplot(1,1,1)
sns.boxplot(y = df['Area Code'])
# Out:
# <AxesSubplot:ylabel='Area Code'>

# %%
len(df)
# Out:
# 60943

# %%
df.shape
# Out:
# (60943, 14)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Area Code', 'Area', 'Item Code', 'Item',
#        'Element Code', 'Element', 'Unit', 'Y2014', 'Y2015', 'Y2016', 'Y2017',
#        'Y2018'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60943, step=1)

# %%
df.groupby('Item').sum()
# Out:
#                      Unnamed: 0  Unnamed: 0.1  Area Code  Item Code  \
# Item
# Alcohol, Non-Food       8771442       8771442      38447     752497
# Alcoholic Beverages    17185991      17185991      75016    1649136
# Animal Products         4003704       4003704      18060     397035
# Animal fats            19691414      19691414      85279    1882494
# Apples and products    15803446      15803446      69280    1352989
# ...                         ...           ...        ...        ...
# Vegetables, Other      17632638      17632638      77779    1518715
# Vegetal Products        4003299       4003299      18060     391905
# Wheat and products     19373714      19373714      87073    1639683
# Wine                   15182242      15182242      66206    1319535
# Yams                   10912246      10912246      50798     970905
#
#                      Element Code      Y2014      Y2015      Y2016      Y2017  \
# Item
# ...

# %%
df.groupby('Element').sum()
# Out:
#                                         Unnamed: 0  Unnamed: 0.1  Area Code  \
# Element
# Domestic supply quantity                 160905858     160905858     708993
# Export Quantity                          136913744     136913744     599910
# Fat supply quantity (g/capita/day)       153145800     153145800     675050
# Feed                                      39612522      39612522     176272
# Food                                     150669420     150669420     663295
# Food supply (kcal/capita/day)            153029448     153029448     674057
# Food supply quantity (kg/capita/yr)      149413695     149413695     658446
# Import Quantity                          156184233     156184233     688174
# Losses                                    62224563      62224563     274353
# Other uses (non-food)                     54007001      54007001     235554
# Processing                                60064377      60064377     271940
# ...

# %%
df.groupby('Area').sum()
# Out:
#                              Unnamed: 0  Unnamed: 0.1  Area Code  Item Code  \
# Area
# Algeria                          861328        861328       5252    3532053
# Angola                          2882888       2882888       9968    3819908
# Benin                           4342015       4342015      68105    3453692
# Botswana                        6491069       6491069      27560    3704902
# Burkina Faso                    8600536       8600536     328297    3778795
# Cabo Verde                      9372510       9372510      44100    3396746
# Cameroon                       12845810      12845810      46720    3916078
# Central African Republic       13709472      13709472      49728    3607546
# Chad                           15503592      15503592      52377    3606529
# Comoros                          550710        550710       2025     124514
# Congo                          18322371      18322371      64998    3792029
# ...
